# %% [markdown]
# <a href="https://colab.research.google.com/github/tw-jameslee/PythonTeach_115/blob/main/Colab/2026_09_09%E4%B8%8A%E8%AA%B2%E7%A8%8B%E5%BC%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 我的第一個Python程式

# %%
"""
我的第一個python程式
日期：2026/09/09
版本：v0.1
作者：李大仁
"""

# 定義3個變數的值
x=100   # 代表把100這個值存放至 變數x 裡
y=200
z=x+y+30

# 將運算結果顯示出來
print(z)
# Out:
# 330
