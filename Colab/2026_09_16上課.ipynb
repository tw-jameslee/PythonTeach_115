# %% [markdown]
# <a href="https://colab.research.google.com/github/tw-jameslee/PythonTeach_115/blob/main/Colab/2026_09_16%E4%B8%8A%E8%AA%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
程式設計進階選修課程(Python)
日期：2026/09/16
版本：v0.1
作者：李大仁
多媒體教材：https://twjames.pse.is/115python-video
"""

# test test
# Out:
# '\n程式設計進階選修課程(Python)\n日期：2026/09/16\n版本：v0.1\n作者：李大仁\n多媒體教材：https://twjames.pse.is/115python-video\n'
